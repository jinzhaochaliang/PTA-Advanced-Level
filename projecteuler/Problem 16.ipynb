# %%
s=1
for i in range(1,1001):
    s=s*2
alist=list(str(s))
alist
# Out:
# ['1',
#  '0',
#  '7',
#  '1',
#  '5',
#  '0',
#  '8',
#  '6',
#  '0',
#  '7',
#  '1',
#  '8',
#  '6',
#  '2',
#  '6',
#  '7',
#  '3',
#  '2',
#  '0',
#  '9',
#  '4',
#  '8',
#  '4',
#  '2',
#  '5',
#  '0',
#  '4',
#  '9',
#  '0',
#  '6',
#  '0',
#  '0',
#  '0',
#  '1',
#  '8',
#  '1',
#  '0',
#  '5',
#  '6',
#  '1',
#  '4',
#  '0',
#  '4',
#  '8',
#  '1',
#  '1',
#  '7',
#  '0',
#  '5',
#  '5',
#  '3',
#  '3',
#  '6',
#  '0',
#  '7',
#  '4',
#  '4',
#  '3',
#  '7',
#  '5',
#  '0',
#  '3',
#  '8',
#  '8',
#  '3',
#  '7',
#  '0',
#  '3',
#  '5',
#  '1',
#  '0',
#  '5',
#  '1',
#  '1',
#  '2',
#  '4',
#  '9',
#  '3',
#  '6',
#  '1',
#  '2',
#  '2',
#  '4',
#  '9',
#  '3',
#  '1',
#  '9',
#  '8',
#  '3',
#  '7',
#  '8',
#  '8',
#  '1',
#  '5',
#  '6',
#  '9',
#  '5',
#  '8',
#  '5',
#  '8',
#  '1',
#  '2',
#  '7',
#  '5',
#  '9',
#  '4',
#  '6',
#  '7',
#  '2',
#  '9',
#  '1',
#  '7',
#  '5',
#  '5',
#  '3',
#  '1',
#  '4',
#  '6',
#  '8',
#  '2',
#  '5',
#  '1',
#  '8',
#  '7',
#  '1',
# ...

# %%
num=0
for el in alist:
    num=num+int(el)
num
# Out:
# 1366
